# %%
#print Statement 
print("HOPE AI")
# Out:
# HOPE AI

# %%
# Buy input  
name = input('Enter your institute name? : ')
# Out:
# Enter your institute name? :  Deiva

# %%
#Buy inputs 
name = input('Enter your name: ') 
age = input('Enter your age: ') 
school = input('Enter your school name: ') 
degree = input('Enter your drgree: ')
# Out:
# Enter your name:  deiva
# Enter your age:  19
# Enter your school name:  REC
# Enter your drgree:  B TECH AIDS

# %%
#Addition 
num1 = int(input("a= ")) 
num2 = int(input("b= ")) 
print("add =",num1+num2)
# Out:
# a=  32
# b=  34
# add = 66

# %%
#Subtraction 
num1 = int(input("a= ")) 
num2 = int(input("b= ")) 
print("Sub =",num1-num2)

# %%
#Multiplication 
num1 = int(input("a= ")) 
num2 = int(input("b= ")) 
print("Mul =",num1*num2) 
a= 63

# %%
#Division 
num1 = int(input("a= ")) 
num2 = int(input("b= ")) 
print("Float Div =",num1/num2)

# %%
#Floor division 
num1 = int(input("a= ")) 
num2 = int(input("b= ")) 
print("Floor Div =",num1 // num2)

# %%
#Modulo 
num1 = int(input("a= ")) 
num2 = int(input("b= ")) 
print("Modulo =",num1 % num2)

# %%
#Power 
num1 = int(input("a= ")) 
num2 = int(input("b= ")) 
print("Power =",num1 ** num2)
